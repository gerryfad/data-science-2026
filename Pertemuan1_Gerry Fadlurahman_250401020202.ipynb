# %% [markdown]
# Nama: Gerry Fadlurahman
# NIM: 250401020202
# Kelas: Data Science IF401
# Dosen Pengampu : Syahid Abdullah, S.Si., M.Kom.

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama       = "Gerry Fadlurahman"     # String
angkatan   = 2026                         # Integer
ipk        = 3.81                         # Float
aktif      = True                         # Boolean
print(f"Nama    : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK     : {ipk}")
print(f"Aktif   : {aktif}")
# Out:
# Nama    : Gerry Fadlurahman
# Angkatan: 2026
# IPK     : 3.81
# Aktif   : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Gerry Fadlurahman", "Informatika", 2026)
print(hasil)
# Out:
# Hai! Saya Gerry Fadlurahman dari Informatika, angkatan 2026.

# %% [markdown]
# # Kesimpulan
#
# Pada pertemuan ini saya mempelajari konsep-konsep dasar Python yang digunakan dalam bidang Data Science, seperti variabel, tipe data, list, perulangan (loop), serta pembuatan fungsi sederhana.
#
# Hasil utama yang diperoleh dari praktikum ini menunjukkan bahwa Python dapat dimanfaatkan untuk mengelola dan memproses data sederhana secara sistematis dan terorganisasi.
#
# Meskipun demikian, pemahaman terhadap logika pemrograman yang lebih kompleks masih perlu ditingkatkan. Oleh karena itu, diperlukan latihan yang lebih intensif, terutama dalam penggunaan fungsi dan pengelolaan struktur data.
